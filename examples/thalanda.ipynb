# %%
"""
Thalanga Drillhole Database Example
===================================

This example demonstrates how to load collar and survey data from the Thalanga dataset
and create a drillhole database using loopresources.
"""

import pandas as pd
import numpy as np
import os
from loopresources.drillhole import DrillholeDatabase, DhConfig

###############################################################################
# Load Thalanga Data
# ------------------
# Load the collar and survey data from the CSV files in the thalanga folder.

# Get the path to the thalanga data folder
data_folder = os.path.join('./', 'thalanga')

# Load collar data
collar_file = os.path.join(data_folder, 'ThalangaML_collar.csv')
collar_raw = pd.read_csv(collar_file)

print("Raw collar data columns:")
print(collar_raw.columns.tolist())
print(f"\nLoaded {len(collar_raw)} collar records")
print(f"First few records:")
print(collar_raw.head())

###############################################################################
# Load survey data
survey_file = os.path.join(data_folder, 'ThalangaML_survey.csv')
survey_raw = pd.read_csv(survey_file)

print(f"\nRaw survey data columns:")
print(survey_raw.columns.tolist())
print(f"\nLoaded {len(survey_raw)} survey records")
print(f"First few records:")
print(survey_raw.head())

###############################################################################
# Prepare Data for loopresources
# -------------------------------
# Map the Thalanga column names to the expected loopresources column names.

# Prepare collar data - map columns to DhConfig expected names
collar = pd.DataFrame({
    DhConfig.holeid: collar_raw['HOLE_ID'],
    DhConfig.x: collar_raw['X_MGA'],  # Easting
    DhConfig.y: collar_raw['Y_MGA'],  # Northing
    DhConfig.z: collar_raw['Z_MGA'],  # Elevation
    DhConfig.total_depth: collar_raw['DEPTH']  # Total depth
})

# Remove any rows with missing essential data
collar = collar.dropna(subset=[DhConfig.holeid, DhConfig.x, DhConfig.y, DhConfig.z, DhConfig.total_depth])

print(f"\nPrepared collar data:")
print(f"Shape: {collar.shape}")
print(collar.head())

###############################################################################
# Prepare survey data - map columns to DhConfig expected names
survey = pd.DataFrame({
    DhConfig.holeid: survey_raw['Drillhole ID'],
    DhConfig.depth: survey_raw['Depth'],
    DhConfig.dip: survey_raw['Dip'],      # Dip in degrees
    DhConfig.azimuth: survey_raw['Azimuth']  # Azimuth in degrees
})

# Remove any rows with missing essential data
survey = survey.dropna(subset=[DhConfig.holeid, DhConfig.depth, DhConfig.dip, DhConfig.azimuth])

print(f"\nPrepared survey data:")
print(f"Shape: {survey.shape}")
print(survey.head())

###############################################################################
# Create DrillHole Database
# -------------------------
# Initialize the DrillholeDatabase with collar and survey data.

# Create the drillhole database
db = DrillholeDatabase(collar=collar, survey=survey)
# Out:
# Raw collar data columns:
# ['HOLE_ID', 'X_MGA', 'Y_MGA', 'Z_MGA', 'DEPTH', 'DATASET', 'PRE_COLLAR', 'RC_DEPTH', 'GRID_NAME', 'START_DATE', 'FINISH_DAT', 'PROSPECT', 'LOCATION', 'COLLAR_COM', 'HOLE_TYPE', 'HOLE_SIZE', 'HOLE_PURPO', 'TENMENT_ID', 'NATIVE_TIT', 'LOCATION_S', 'CONTRACTOR', 'COMPANY', 'PROGRAM_NA', 'GEOLOGIST', 'LOGGED_BY', 'DRILLING_S', 'EQUIPMENT_', 'GROUTED', 'MINING_LEV', 'PLANNED_DE', 'PLANNED_AZ', 'PLANNED_DI', 'TENEMENT_I']
#
# Loaded 5277 collar records
# First few records:
#       HOLE_ID     X_MGA      Y_MGA   Z_MGA      DEPTH   DATASET  PRE_COLLAR  \
# 0  C2034NEI32  371427.0  7750416.0  146.90  98.500000  THALANGA         NaN
# 1   C2035ND39  371452.0  7750425.0  219.67  59.100000  THALANGA         NaN
# 2  C2035NED25  371439.0  7750397.0  219.00  69.700000  THALANGA         NaN
# 3  C2035NEI14  371439.0  7750397.0  222.00  71.700000  THALANGA         NaN
# 4   C2035NI10  371452.0  7750425.0  220.96  32.200001  THALANGA         NaN
#
#    RC_DEPTH  GRID_NAME START_DATE  ... GEOLOGIST LOGGED_BY DRILLING_S  \
# 0       NaN  MGA_94_55        NaN  ...       NaN       NaN        NaN
# 1       NaN  MGA_94_55        NaN  ...       NaN       NaN        NaN
# 2       NaN  MGA_94_55        NaN  ...       NaN       NaN        NaN
# 3       NaN  MGA_94_55        NaN  ...       NaN       NaN        NaN
# 4       NaN  MGA_94_55        NaN  ...       NaN       NaN        NaN
#
#   EQUIPMENT_ GROUTED MINING_LEV PLANNED_DE PLANNED_AZ PLANNED_DI TENEMENT_I
# 0        NaN     NaN        NaN        NaN        NaN        NaN        UNK
# 1        NaN     NaN        NaN        NaN        NaN        NaN        UNK
# 2        NaN     NaN        NaN        NaN        NaN        NaN        UNK
# 3        NaN     NaN        NaN        NaN        NaN        NaN        UNK
# 4        NaN     NaN        NaN        NaN        NaN        NaN        UNK
#
# [5 rows x 33 columns]
#
# Raw survey data columns:
# ['Drillhole ID', 'Depth', 'Dip', 'Azimuth']
#
# Loaded 18855 survey records
# First few records:
#   Drillhole ID  Depth  Dip   Azimuth
# 0          C26    8.0  0.0  27.31485
# 1          C27    0.0  0.0  35.81485
# 2          C27    3.0  0.0  35.81485
# 3          C28    0.0  0.0  25.81485
# 4          C28    7.0  0.0  25.81485
#
# Prepared collar data:
# Shape: (5277, 5)
#        HOLEID      EAST      NORTH      RL      DEPTH
# 0  C2034NEI32  371427.0  7750416.0  146.90  98.500000
# 1   C2035ND39  371452.0  7750425.0  219.67  59.100000
# 2  C2035NED25  371439.0  7750397.0  219.00  69.700000
# 3  C2035NEI14  371439.0  7750397.0  222.00  71.700000
# 4   C2035NI10  371452.0  7750425.0  220.96  32.200001
#
# Prepared survey data:
# Shape: (18855, 4)
#   HOLEID  DEPTH  DIP   AZIMUTH
# 0    C26    8.0  0.0  27.31485
# 1    C27    0.0  0.0  35.81485
# 2    C27    3.0  0.0  35.81485
# 3    C28    0.0  0.0  25.81485
# 4    C28    7.0  0.0  25.81485

# %%
for h in db:
    print(h)
# Out:
# DrillHole: C2034NEI32
# =====================
# Location: X=371427.00, Y=7750416.00, Z=146.90
# Total Depth: 98.50m
# Average Azimuth: 39.71°
# Average Dip: -32.30°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2035ND39
# ====================
# Location: X=371452.00, Y=7750425.00, Z=219.67
# Total Depth: 59.10m
# Average Azimuth: 21.81°
# Average Dip: 40.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2035NED25
# =====================
# Location: X=371439.00, Y=7750397.00, Z=219.00
# Total Depth: 69.70m
# Average Azimuth: 24.31°
# Average Dip: 26.10°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2035NEI14
# =====================
# Location: X=371439.00, Y=7750397.00, Z=222.00
# Total Depth: 71.70m
# Average Azimuth: 25.41°
# Average Dip: -14.04°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2035NI10
# ====================
# Location: X=371452.00, Y=7750425.00, Z=220.96
# Total Depth: 32.20m
# Average Azimuth: 22.15°
# Average Dip: -10.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2035NI30
# ====================
# Location: X=371435.00, Y=7750390.00, Z=148.29
# Total Depth: 100.20m
# Average Azimuth: 23.15°
# Average Dip: -29.07°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2036NI30
# ====================
# Location: X=371453.00, Y=7750402.00, Z=223.13
# Total Depth: 65.00m
# Average Azimuth: 10.15°
# Average Dip: -29.40°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2037ND24
# ====================
# Location: X=371457.00, Y=7750391.00, Z=220.47
# Total Depth: 71.50m
# Average Azimuth: 23.69°
# Average Dip: 21.70°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2037ND30
# ====================
# Location: X=371457.00, Y=7750390.00, Z=220.60
# Total Depth: 60.60m
# Average Azimuth: 23.31°
# Average Dip: 31.83°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2037NH00
# ====================
# Location: X=371457.00, Y=7750390.00, Z=221.32
# Total Depth: 60.00m
# Average Azimuth: 22.31°
# Average Dip: -0.33°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2037NI15
# ====================
# Location: X=371453.00, Y=7750381.00, Z=150.15
# Total Depth: 81.80m
# Average Azimuth: 24.81°
# Average Dip: -14.20°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2037NI23
# ====================
# Location: X=371457.00, Y=7750390.00, Z=222.21
# Total Depth: 69.10m
# Average Azimuth: 23.31°
# Average Dip: -23.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2037NI32
# ====================
# Location: X=371452.00, Y=7750382.00, Z=150.84
# Total Depth: 92.20m
# Average Azimuth: 24.06°
# Average Dip: -31.70°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2038ND25
# ====================
# Location: X=371467.00, Y=7750387.00, Z=220.30
# Total Depth: 60.40m
# Average Azimuth: 22.31°
# Average Dip: 25.33°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2039ND01
# ====================
# Location: X=371470.00, Y=7750373.00, Z=152.47
# Total Depth: 80.80m
# Average Azimuth: 24.66°
# Average Dip: 2.05°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2039ND20
# ====================
# Location: X=371470.00, Y=7750372.00, Z=151.80
# Total Depth: 74.40m
# Average Azimuth: 23.56°
# Average Dip: 17.82°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2039ND25
# ====================
# Location: X=371476.00, Y=7750385.00, Z=218.78
# Total Depth: 70.50m
# Average Azimuth: 23.69°
# Average Dip: 22.90°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2039NED20
# =====================
# Location: X=371477.00, Y=7750385.00, Z=219.05
# Total Depth: 60.00m
# Average Azimuth: 51.81°
# Average Dip: 20.30°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2039NEI01
# =====================
# Location: X=371471.00, Y=7750372.00, Z=153.63
# Total Depth: 65.70m
# Average Azimuth: 36.15°
# Average Dip: -1.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2039NEI28
# =====================
# Location: X=371471.00, Y=7750373.00, Z=155.22
# Total Depth: 81.30m
# Average Azimuth: 39.19°
# Average Dip: -27.70°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2039NH00
# ====================
# Location: X=371476.00, Y=7750385.00, Z=219.38
# Total Depth: 50.00m
# Average Azimuth: 23.71°
# Average Dip: -0.13°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2039NI20
# ====================
# Location: X=371471.00, Y=7750373.00, Z=153.46
# Total Depth: 70.20m
# Average Azimuth: 23.31°
# Average Dip: -17.87°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2039NI25
# ====================
# Location: X=371476.00, Y=7750385.00, Z=220.32
# Total Depth: 54.30m
# Average Azimuth: 23.81°
# Average Dip: -25.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2039NI33
# ====================
# Location: X=371471.00, Y=7750373.00, Z=155.46
# Total Depth: 73.30m
# Average Azimuth: 25.06°
# Average Dip: -31.25°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2039NI45
# ====================
# Location: X=371471.00, Y=7750373.00, Z=156.39
# Total Depth: 50.00m
# Average Azimuth: 23.48°
# Average Dip: -44.93°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2040SED50
# =====================
# Location: X=371469.00, Y=7750383.00, Z=221.50
# Total Depth: 168.50m
# Average Azimuth: 194.44°
# Average Dip: 47.31°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2041ND08
# ====================
# Location: X=371493.00, Y=7750371.00, Z=155.11
# Total Depth: 48.60m
# Average Azimuth: 23.56°
# Average Dip: 7.05°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2041ND31
# ====================
# Location: X=371493.00, Y=7750371.00, Z=154.52
# Total Depth: 58.40m
# Average Azimuth: 21.81°
# Average Dip: 28.80°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2041ND36
# ====================
# Location: X=371496.00, Y=7750379.00, Z=215.06
# Total Depth: 53.40m
# Average Azimuth: 24.36°
# Average Dip: 35.42°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2041ND68
# ====================
# Location: X=371505.00, Y=7750375.00, Z=215.00
# Total Depth: 29.50m
# Average Azimuth: 30.35°
# Average Dip: 67.93°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2041NH00
# ====================
# Location: X=371497.00, Y=7750379.00, Z=215.98
# Total Depth: 50.30m
# Average Azimuth: 24.59°
# Average Dip: -1.25°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2041NI18
# ====================
# Location: X=371493.00, Y=7750371.00, Z=156.07
# Total Depth: 50.60m
# Average Azimuth: 24.56°
# Average Dip: -17.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2041NI32
# ====================
# Location: X=371496.00, Y=7750379.00, Z=217.27
# Total Depth: 60.50m
# Average Azimuth: 26.44°
# Average Dip: -31.80°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2041SI05
# ====================
# Location: X=371494.00, Y=7750375.00, Z=216.18
# Total Depth: 90.50m
# Average Azimuth: 204.41°
# Average Dip: -4.70°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2042NI40
# ====================
# Location: X=371515.00, Y=7750377.00, Z=215.77
# Total Depth: 42.20m
# Average Azimuth: 25.81°
# Average Dip: -40.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2042NI42
# ====================
# Location: X=371515.00, Y=7750376.00, Z=215.71
# Total Depth: 33.70m
# Average Azimuth: 25.81°
# Average Dip: -42.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2043ND05
# ====================
# Location: X=371517.00, Y=7750376.00, Z=213.49
# Total Depth: 56.80m
# Average Azimuth: 25.19°
# Average Dip: 4.70°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2043ND08
# ====================
# Location: X=371507.00, Y=7750355.00, Z=230.37
# Total Depth: 75.00m
# Average Azimuth: 25.98°
# Average Dip: 6.87°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2043ND31
# ====================
# Location: X=371509.00, Y=7750359.00, Z=157.45
# Total Depth: 51.00m
# Average Azimuth: 27.31°
# Average Dip: 27.13°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2043ND38
# ====================
# Location: X=371517.00, Y=7750376.00, Z=212.61
# Total Depth: 40.50m
# Average Azimuth: 18.06°
# Average Dip: 39.20°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2043NH00
# ====================
# Location: X=371509.00, Y=7750359.00, Z=157.98
# Total Depth: 44.60m
# Average Azimuth: 25.81°
# Average Dip: -0.87°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2043NI19
# ====================
# Location: X=371507.00, Y=7750355.00, Z=231.32
# Total Depth: 73.10m
# Average Azimuth: 22.38°
# Average Dip: -17.93°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2043NI30
# ====================
# Location: X=371509.00, Y=7750359.00, Z=159.27
# Total Depth: 89.40m
# Average Azimuth: 24.81°
# Average Dip: -30.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2043SD43
# ====================
# Location: X=371496.00, Y=7750323.00, Z=192.00
# Total Depth: 97.00m
# Average Azimuth: 209.71°
# Average Dip: 41.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2043SI13
# ====================
# Location: X=371514.00, Y=7750369.00, Z=214.06
# Total Depth: 90.20m
# Average Azimuth: 206.31°
# Average Dip: -12.28°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2045ND05
# ====================
# Location: X=371525.00, Y=7750346.00, Z=232.69
# Total Depth: 43.00m
# Average Azimuth: 25.81°
# Average Dip: 4.40°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2045ND30
# ====================
# Location: X=371534.00, Y=7750363.00, Z=162.83
# Total Depth: 34.50m
# Average Azimuth: 25.15°
# Average Dip: 27.40°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2045ND32
# ====================
# Location: X=371525.00, Y=7750346.00, Z=232.14
# Total Depth: 50.70m
# Average Azimuth: 27.31°
# Average Dip: 31.10°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2045NI19
# ====================
# Location: X=371534.00, Y=7750363.00, Z=164.17
# Total Depth: 77.60m
# Average Azimuth: 26.01°
# Average Dip: -17.12°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2045NI48
# ====================
# Location: X=371534.00, Y=7750363.00, Z=165.66
# Total Depth: 50.60m
# Average Azimuth: 23.81°
# Average Dip: -44.83°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2045SEH00
# =====================
# Location: X=371495.00, Y=7750316.00, Z=194.60
# Total Depth: 37.80m
# Average Azimuth: 129.81°
# Average Dip: -0.50°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2047ND11
# ====================
# Location: X=371543.00, Y=7750338.00, Z=235.03
# Total Depth: 56.10m
# Average Azimuth: 24.48°
# Average Dip: 10.43°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2047ND27
# ====================
# Location: X=371551.00, Y=7750354.00, Z=164.61
# Total Depth: 50.60m
# Average Azimuth: 23.48°
# Average Dip: 26.93°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2047ND28
# ====================
# Location: X=371543.00, Y=7750338.00, Z=234.64
# Total Depth: 65.30m
# Average Azimuth: 25.55°
# Average Dip: 27.07°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2047NH00
# ====================
# Location: X=371551.00, Y=7750354.00, Z=165.18
# Total Depth: 42.00m
# Average Azimuth: 24.81°
# Average Dip: -1.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2047NI09
# ====================
# Location: X=371543.00, Y=7750338.00, Z=235.65
# Total Depth: 47.80m
# Average Azimuth: 23.81°
# Average Dip: -9.70°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2047NI14
# ====================
# Location: X=371543.00, Y=7750338.00, Z=235.86
# Total Depth: 42.00m
# Average Azimuth: 21.81°
# Average Dip: -15.35°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2047NI20
# ====================
# Location: X=371543.00, Y=7750338.00, Z=236.09
# Total Depth: 52.70m
# Average Azimuth: 21.98°
# Average Dip: -20.43°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2047NI31
# ====================
# Location: X=371551.00, Y=7750354.00, Z=166.50
# Total Depth: 56.10m
# Average Azimuth: 26.06°
# Average Dip: -27.22°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2047SD46
# ====================
# Location: X=371534.00, Y=7750320.00, Z=177.50
# Total Depth: 124.00m
# Average Azimuth: 207.15°
# Average Dip: 43.17°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2047SI47
# ====================
# Location: X=371534.00, Y=7750320.00, Z=182.00
# Total Depth: 24.00m
# Average Azimuth: 30.81°
# Average Dip: -48.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2048NEI07
# =====================
# Location: X=371542.00, Y=7750305.00, Z=257.00
# Total Depth: 54.40m
# Average Azimuth: 52.65°
# Average Dip: -7.93°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2048SI55
# ====================
# Location: X=371539.00, Y=7750308.00, Z=183.00
# Total Depth: 88.10m
# Average Azimuth: 209.48°
# Average Dip: -53.33°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2049ND10
# ====================
# Location: X=371578.00, Y=7750345.00, Z=239.28
# Total Depth: 44.20m
# Average Azimuth: 23.31°
# Average Dip: 9.15°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2049ND17
# ====================
# Location: X=371566.00, Y=7750339.00, Z=164.57
# Total Depth: 61.00m
# Average Azimuth: 22.19°
# Average Dip: 16.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2049ND37
# ====================
# Location: X=371578.00, Y=7750344.00, Z=239.78
# Total Depth: 60.50m
# Average Azimuth: 5.31°
# Average Dip: 35.87°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2049NI02
# ====================
# Location: X=371566.00, Y=7750339.00, Z=165.05
# Total Depth: 64.00m
# Average Azimuth: 23.81°
# Average Dip: -0.90°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2049NI24
# ====================
# Location: X=371566.00, Y=7750339.00, Z=166.23
# Total Depth: 71.40m
# Average Azimuth: 25.15°
# Average Dip: -24.33°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2049NI25
# ====================
# Location: X=371578.00, Y=7750344.00, Z=240.65
# Total Depth: 44.70m
# Average Azimuth: 4.31°
# Average Dip: -25.40°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2051ND18
# ====================
# Location: X=371588.00, Y=7750341.00, Z=237.66
# Total Depth: 46.30m
# Average Azimuth: 20.21°
# Average Dip: 18.25°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2051ND41
# ====================
# Location: X=371588.00, Y=7750341.00, Z=237.06
# Total Depth: 55.20m
# Average Azimuth: 17.81°
# Average Dip: 41.30°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2051NI21
# ====================
# Location: X=371588.00, Y=7750340.00, Z=238.82
# Total Depth: 47.00m
# Average Azimuth: 27.56°
# Average Dip: -20.65°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2053ND10
# ====================
# Location: X=371608.00, Y=7750336.00, Z=235.11
# Total Depth: 42.80m
# Average Azimuth: 23.06°
# Average Dip: 9.90°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2053ND40
# ====================
# Location: X=371608.00, Y=7750336.00, Z=234.40
# Total Depth: 54.80m
# Average Azimuth: 24.51°
# Average Dip: 37.73°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2053NI35
# ====================
# Location: X=371608.00, Y=7750336.00, Z=236.46
# Total Depth: 23.40m
# Average Azimuth: 25.81°
# Average Dip: -35.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2055ND39
# ====================
# Location: X=371615.00, Y=7750306.00, Z=243.39
# Total Depth: 95.30m
# Average Azimuth: 24.01°
# Average Dip: 36.88°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2055ND65
# ====================
# Location: X=371615.00, Y=7750305.00, Z=243.17
# Total Depth: 51.00m
# Average Azimuth: 23.44°
# Average Dip: 65.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2055NED33
# =====================
# Location: X=371615.00, Y=7750306.00, Z=243.54
# Total Depth: 59.40m
# Average Azimuth: 49.81°
# Average Dip: 33.00°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2055NED49
# =====================
# Location: X=371615.00, Y=7750306.00, Z=243.39
# Total Depth: 71.60m
# Average Azimuth: 48.06°
# Average Dip: 48.12°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2055NI03
# ====================
# Location: X=371615.00, Y=7750306.00, Z=244.51
# Total Depth: 74.10m
# Average Azimuth: 24.81°
# Average Dip: -1.86°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2055NWD18
# =====================
# Location: X=371613.00, Y=7750313.00, Z=244.06
# Total Depth: 65.70m
# Average Azimuth: 12.69°
# Average Dip: 17.12°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C2055NWD35
# =====================
# Location: X=371615.00, Y=7750313.00, Z=243.67
# Total Depth: 86.00m
# Average Azimuth: 11.21°
# Average Dip: 33.50°
#
# Interval Tables: None
#
# Point Tables: None
# DrillHole: C

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for h in db:
#       2     print(h)
#
# File ~/dev/loopresources/loopresources/drillhole/drillhole_database.py:1202, in DrillholeDatabase.__iter__(self)
#    1188 """
#    1189 Iterate over all DrillHole objects in the database.
#    1190
#    (...)   1199 ...     print(drillhole.hole_id)
#    1200 """
#    1201 for hole_id in self.list_holes():
# -> 1202     yield self[hole_id]
#
# File ~/dev/loopresources/loopresources/drillhole/drillhole_database.py:1185, in DrillholeDatabase.__getitem__(self, hole_id)
#    1171 def __getitem__(self, hole_id: str) -> DrillHole:
#    1172     """
#    1173     Return a DrillHole view for a given HOLE_ID.
#    1174
#    (...)   1183         A view of this database for the specified hole
#    1184     """
# -> 1185     return DrillHole(self, hole_id)
#
# File ~/dev/loopresources/loopresources/drillhole/drillhole_database.py:45, in DrillHole.__init__(self, database, hole_id)
#      42 # Use optimized methods to get data for this hole
#      43 # For file backend, this queries the database directly
#      44 self.collar = self.database.get_collar_for_hole(hole_id)
# ---> 45 self.survey = self.database.get_survey_for_hole(hole_id)
#      47 if self.collar.empty:
#      48     raise ValueError(f"Hole {hole_id} not found in collar data")
#
# File ~/dev/loopresources/loopresources/drillhole/drillhole_database.py:642, in DrillholeDatabase.get_survey_for_hole(self, hole_id)
#     640     survey_data = self.survey
#     641     mask = survey_data[DhConfig.holeid] == hole_id
# --> 642     return survey_data[mask].copy()
#     643 else:
#     644     return self._load_table_from_db('survey', hole_id=hole_id)
#
# File ~/miniconda3/envs/loopdev/lib/python3.12/site-packages/pandas/core/frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~/miniconda3/envs/loopdev/lib/python3.12/site-packages/pandas/core/frame.py:4151, in DataFrame._getitem_bool_array(self, key)
#    4147 # check_bool_indexer will throw exception if Series key cannot
#    4148 # be reindexed to match DataFrame rows
#    4149 key = check_bool_indexer(self.index, key)
# -> 4151 if key.all():
#    4152     return self.copy(deep=None)
#    4154 indexer = key.nonzero()[0]
#
# File ~/miniconda3/envs/loopdev/lib/python3.12/site-packages/numpy/core/_methods.py:64, in _all(a, axis, dtype, out, keepdims, where)
#      61 def _all(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      62     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      63     if where is True:
# ---> 64         return umr_all(a, axis, dtype, out, keepdims)
#      65     return umr_all(a, axis, dtype, out, keepdims, where=where)
#
# KeyboardInterrupt:

# %%
assays = pd.read_csv('./thalanga/ThalangaML_Assays.csv')
# Out:
# /var/folders/qw/6s0wf2w90mdg7l6ktlxsgv2hzhv43j/T/ipykernel_50201/248949288.py:1: DtypeWarning: Columns (22,23,28,29,30,43,44,48,49,50,76,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   assays = pd.read_csv('./thalanga/ThalangaML_Assays.csv')

# %%
assays.rename(columns={'Drillhole ID': DhConfig.holeid,
                       'From': DhConfig.sample_from,
                       'To': DhConfig.sample_to}, inplace=True)

# %%
lithology = pd.read_csv('./thalanga/ThalangaML_Geology.csv')

# %%
lithology.rename(columns={'Drillhole ID': DhConfig.holeid,
                         'From': DhConfig.sample_from,
                         'To': DhConfig.sample_to}, inplace=True)

# %%
db.add_interval_table('lithology',lithology)

# %%
db.intervals['lithology'].columns
# Out:
# Index(['HOLEID', 'SAMPFROM', 'SAMPTO', 'ALT1', 'ALT1_INTENSITY', 'COLOUR 1',
#        'FORMATION', 'GRAIN_SIZE', 'LITH1_legacy', 'Lith1_Validated',
#        'LITH2_legacy', 'MIN_2', 'MIN1_STYLE', 'REGOLITH', 'TEXTURE',
#        'VALIDATION_ Comment'],
#       dtype='object')

# %%
import pyvista as pv
p = pv.Plotter()
filtered_db = db.filter(holes=db.list_holes()[:100])
for h in filtered_db.list_holes():
    p.add_mesh(filtered_db[h].vtk(newinterval=1.0, properties=['lithology'],radius=1),scalars='lithology_Lith1_Validated')
p.show()
# Out:
# /Users/lgrose/miniconda3/envs/loopdev/lib/python3.12/site-packages/pyvista/plotting/mapper.py:675: RuntimeWarning: All-NaN axis encountered
#   clim = [np.nanmin(scalars), np.nanmax(scalars)]
# /Users/lgrose/miniconda3/envs/loopdev/lib/python3.12/site-packages/pyvista/plotting/mapper.py:675: RuntimeWarning: All-NaN axis encountered
#   clim = [np.nanmin(scalars), np.nanmax(scalars)]
# /Users/lgrose/miniconda3/envs/loopdev/lib/python3.12/site-packages/pyvista/plotting/mapper.py:675: RuntimeWarning: All-NaN axis encountered
#   clim = [np.nanmin(scalars), np.nanmax(scalars)]
# /Users/lgrose/miniconda3/envs/loopdev/lib/python3.12/site-packages/pyvista/plotting/mapper.py:675: RuntimeWarning: All-NaN axis encountered
#   clim = [np.nanmin(scalars), np.nanmax(scalars)]
# /Users/lgrose/miniconda3/envs/loopdev/lib/python3.12/site-packages/pyvista/plotting/mapper.py:675: RuntimeWarning: All-NaN axis encountered
#   clim = [np.nanmin(scalars), np.nanmax(scalars)]
# Widget(value='<iframe src="http://localhost:49430/index.html?ui=P_0x319092d50_8&reconnect=auto" class="pyvista…

# %%
# Let's debug step by step
print("Available holes:", db.list_holes()[:5])
print("\nLithology table columns:", db.intervals['lithology'].columns.tolist())

# Try creating VTK for a single hole first
test_hole = db[db.list_holes()[0]]
print(f"\nTesting hole: {test_hole.hole_id}")

# Check if lithology data exists for this hole
lithology_data = test_hole['lithology']
print(f"Lithology data shape for this hole: {lithology_data.shape}")
if not lithology_data.empty:
    print("Lithology columns for this hole:", lithology_data.columns.tolist())
    print("Sample of lithology data:")
    print(lithology_data.head())
# Out:
# Available holes: ['C2034NEI32', 'C2035ND39', 'C2035NED25', 'C2035NEI14', 'C2035NI10']
#
# Lithology table columns: ['HOLEID', 'SAMPFROM', 'SAMPTO', 'ALT1', 'ALT1_INTENSITY', 'COLOUR 1', 'FORMATION', 'GRAIN_SIZE', 'LITH1_legacy', 'Lith1_Validated', 'LITH2_legacy', 'MIN_2', 'MIN1_STYLE', 'REGOLITH', 'TEXTURE', 'VALIDATION_ Comment']
#
# Testing hole: C2034NEI32
# Lithology data shape for this hole: (16, 16)
# Lithology columns for this hole: ['HOLEID', 'SAMPFROM', 'SAMPTO', 'ALT1', 'ALT1_INTENSITY', 'COLOUR 1', 'FORMATION', 'GRAIN_SIZE', 'LITH1_legacy', 'Lith1_Validated', 'LITH2_legacy', 'MIN_2', 'MIN1_STYLE', 'REGOLITH', 'TEXTURE', 'VALIDATION_ Comment']
# Sample of lithology data:
#            HOLEID   SAMPFROM     SAMPTO ALT1 ALT1_INTENSITY COLOUR 1  \
# 34130  C2034NEI32   0.000000  19.660000   qu            0.0       lp
# 34131  C2034NEI32  19.660000  21.969999  NaN            0.0      NaN
# 34132  C2034NEI32  21.969999  24.799999  NaN            0.0      NaN
# 34133  C2034NEI32  24.799999  26.450001  NaN            0.0      NaN
# 34134  C2034NEI32  26.450001  28.150000  NaN            0.0      NaN
#
#       FORMATION GRAIN_SIZE LITH1_legacy Lith1_Validated LITH2_legacy MIN_2  \
# 34130        HV         VT           RH              RH          NaN    CR
# 34131        HV         MG           RH              RH          NaN   NaN
# 34132        HV         FG           RH              RH          NaN   NaN
# 34133        OH         MG           QE              QE          NaN   NaN
# 34134        OH         FG           RH              RH          NaN   NaN
#
#       MIN1_STYLE REGOLITH TEXTURE VALIDATION_ Comment
# 34130         HA      NaN      po                 NaN
# 34131         QU      NaN      fo                 NaN
# 34132         QU      NaN      fo                 NaN
# 34133         QU      NaN      ct                 NaN
# 34134         QU      NaN      mo                 NaN

# %%
db.filter(holes=db.list_holes()[:10])['C2035NED25'].vtk()
# Out:
# Empty DataFrame
# Columns: [HOLEID, SAMPFROM, SAMPTO, ALT1, ALT1_INTENSITY, COLOUR 1, FORMATION, GRAIN_SIZE, LITH1_legacy, Lith1_Validated, LITH2_legacy, MIN_2, MIN1_STYLE, REGOLITH, TEXTURE, VALIDATION_ Comment]
# Index: []

# %%
db.filter(holes=db.list_holes()[:10])[db.list_holes()[0]].vtk(newinterval=1.0, properties=['lithology']).plot(scalars='lithology_Lith1_Validated')
# Out:
# Widget(value='<iframe src="http://localhost:64129/index.html?ui=P_0x347bdad80_4&reconnect=auto" class="pyvista…

# %%
db[db.list_holes()[1]].vtk(newinterval=1.0, properties=['lithology']).plot(scalars='lithology_Lith1_Validated')
# Out:
# Widget(value='<iframe src="http://localhost:65011/index.html?ui=P_0x3395cb470_0&reconnect=auto" class="pyvista…

# %%
db.filter()
# Out:
#        HOLEID  SAMPFROM  SAMPTO  AG_PPM_LAB  AI_IND  AL_PCT  AL_PPM_LAB  \
# 13  C2035ND39       0.0     1.0         9.0     NaN     NaN         NaN
# 14  C2035ND39       1.0     2.0         5.0     NaN     NaN         NaN
# 15  C2035ND39       2.0     3.0        11.0     NaN     NaN         NaN
# 16  C2035ND39       3.0     4.2        17.0     NaN     NaN         NaN
# 17  C2035ND39       4.2     5.0       225.0     NaN     NaN         NaN
# 18  C2035ND39       5.0     6.0       224.0     NaN     NaN         NaN
# 19  C2035ND39       6.0     7.0       195.0     NaN     NaN         NaN
# 20  C2035ND39       7.0     8.0       104.0     NaN     NaN         NaN
# 21  C2035ND39       8.0     9.0       170.0     NaN     NaN         NaN
# 22  C2035ND39       9.0    10.0       206.0     NaN     NaN         NaN
# 23  C2035ND39      10.0    11.0       172.0     NaN     NaN         NaN
# 24  C2035ND39      11.0    12.0       401.0     NaN     NaN         NaN
# 25  C2035ND39      12.0    13.0       196.0     NaN     NaN         NaN
# 26  C2035ND39      13.0    14.0       135.0     NaN     NaN         NaN
# 27  C2035ND39      14.0    15.0       104.0     NaN     NaN         NaN
# 28  C2035ND39      15.0    16.0       288.0     NaN     NaN         NaN
# 29  C2035ND39      16.0    17.0       245.0     NaN     NaN         NaN
# 30  C2035ND39      17.0    18.0        84.0     NaN     NaN         NaN
# 31  C2035ND39      18.0    19.0       126.0     NaN     NaN         NaN
# 32  C2035ND39      19.0    20.0       106.0     NaN     NaN         NaN
# 33  C2035ND39      20.0    21.0       200.0     NaN     NaN         NaN
# 34  C2035ND39      21.0    22.0       137.0     NaN     NaN         NaN
# 35  C2035ND39      22.0    23.0       256.0     NaN     NaN         NaN
# 36  C2035ND39      23.0    24.0       233.0     NaN     NaN         NaN
# 37  C2035ND39      24.0    25.0        37.0     NaN     NaN         NaN
# 38  C2035ND39      25.0    26.0        15.0     NaN     NaN         NaN
# 39  C2035ND39      26.0    27.0        29.0     NaN     NaN         NaN
# 40  C2035ND39      27.0    28.0        81.0     NaN     NaN         NaN
# 41  C2035ND39      28.0    29.0        19.0     NaN     NaN         NaN
# 42  C2035ND39      29.0    30.0        28.0     NaN     NaN         NaN
# 43  C2035ND39      30.0    31.0        20.0     NaN     NaN         NaN
# 44  C2035ND39      31.0    32.0        14.0     NaN     NaN         NaN
# 45  C2035ND39      39.0    40.0        20.0     NaN     NaN         NaN
# 46  C2035ND39      40.0    41.0         8.0     NaN     NaN         NaN
# 47  C2035ND39      41.0    42.0        13.0     NaN     NaN         NaN
# 48  C2035ND39      42.0    43.0        17.0     NaN     NaN         NaN
# 49  C2035ND39      43.0    44.0        12.0     NaN     NaN         NaN
# 50  C2035ND39      44.0    45.0         7.0     NaN     NaN         NaN
#
#     AS_PPM_LAB  AU_PPM_LAB  Ba_K2O  ...  W_PPM_LAB  WIDTH  Y_PPM_LAB  \
# 13         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 14         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 15         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 16         NaN         NaN     NaN  ...        NaN    1.2        NaN
# 17         NaN         NaN     NaN  ...        NaN    0.8        NaN
# 18         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 19         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 20         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 21         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 22         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 23         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 24         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 25         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 26         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 27         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 28         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 29         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 30         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 31         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 32         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 33         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 34         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 35         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 36         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 37         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 38         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 39         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 40         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 41         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 42         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 43         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 44         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 45         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 46         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 47         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 48         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 49         NaN         NaN     NaN  ...        NaN    1.0        NaN
# 50         NaN         NaN     NaN  ...        NaN    1.0        NaN
#
#     YB_PPM_LAB  Zn_pct  ZN_PPM_LAB  Zn_Zn_Pb       ZnEq      ZnEqm  ZR_PPM_LAB
# 13         NaN    0.59      5900.0     0.738   1.565000   1.565000         NaN
# 14         NaN    0.13      1300.0     0.813   0.315000   0.315000         NaN
# 15         NaN    0.15      1500.0     0.682   0.587000   0.587000         NaN
# 16         NaN    2.10     21000.0     0.833   3.926000   4.711200         NaN
# 17         NaN   23.00    230000.0     0.697  40.826000  32.660801         NaN
# 18         NaN   23.00    230000.0     0.655  41.799999  41.799999         NaN
# 19         NaN   17.60    176000.0     0.595  39.049999  39.049999         NaN
# 20         NaN   27.00    270000.0     0.850  39.296001  39.296001         NaN
# 21         NaN   21.00    210000.0     0.752  39.125000  39.125000         NaN
# 22         NaN   21.00    210000.0     0.719  39.676998  39.676998         NaN
# 23         NaN   17.00    170000.0     0.683  29.829000  29.829000         NaN
# 24         NaN   22.00    220000.0     0.595  55.424999  55.424999         NaN
# 25         NaN   20.00    200000.0     0.711  40.698002  40.698002         NaN
# 26         NaN   16.00    160000.0     0.726  35.238998  35.238998         NaN
# 27         NaN   14.00    140000.0     0.771  28.660000  28.660000         NaN
# 28         NaN   18.00    180000.0     0.694  41.346001  41.346001         NaN
# 29         NaN   23.00    230000.0     0.701  43.224998  43.224998         NaN
# 30         NaN   21.00    210000.0     0.839  31.479000  31.479000         NaN
# 31         NaN   19.00    190000.0     0.734  33.688000  33.688000         NaN
# 32         NaN   18.00    180000.0     0.735  36.268002  36.268002         NaN
# 33         NaN   21.00    210000.0     0.671  43.157001  43.157001         NaN
# 34         NaN   16.50    165000.0     0.713  30.785000  30.785000         NaN
# 35         NaN   20.00    200000.0     0.627  39.354000  39.354000         NaN
# 36         NaN   17.00    170000.0     0.704  43.393002  43.393002         NaN
# 37         NaN    2.20     22000.0     0.824  24.635000  24.635000         NaN
# 38         NaN    0.52      5200.0     0.825  10.300000  10.300000         NaN
# 39         NaN    1.21     12100.0     0.864  15.141000  15.141000         NaN
# 40         NaN    2.50     25000.0     0.812  32.766998  32.766998         NaN
# 41         NaN    0.82      8200.0     0.911  17.009001  17.009001         NaN
# 42         NaN    0.50      5000.0     0.847  14.547000  14.547000         NaN
# 43         NaN    0.23      2300.0     0.821   2.887000   2.887000         NaN
# 44         NaN    0.70      7000.0     0.933   1.755000   1.755000         NaN
# 45         NaN    0.96      9600.0     0.821   2.243000   2.243000         NaN
# 46         NaN    0.31      3100.0     0.756   2.217000   2.217000         NaN
# 47         NaN    0.52      5200.0     0.722   1.454000   1.454000         NaN
# 48         NaN    0.74      7400.0     0.712   2.293000   2.293000         NaN
# 49         NaN    0.54      5400.0     0.651   1.596000   1.596000         NaN
# 50         NaN    0.25      2500.0     0.714   0.845000   0.845000         NaN
#
# [38 rows x 107 columns]

# %%
db
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 db['assays']
#
# File ~/dev/loopresources/loopresources/drillhole/drillhole_database.py:950, in DrillholeDatabase.__getitem__(self, hole_id)
#     936 def __getitem__(self, hole_id: str) -> DrillHole:
#     937     """
#     938     Return a DrillHole view for a given HOLE_ID.
#     939
#    (...)    948         A view of this database for the specified hole
#     949     """
# --> 950     return DrillHole(self, hole_id)
#
# File ~/dev/loopresources/loopresources/drillhole/drillhole_database.py:47, in DrillHole.__init__(self, database, hole_id)
#      44 self.survey = self.database.get_survey_for_hole(hole_id)
#      46 if self.collar.empty:
# ---> 47     raise ValueError(f"Hole {hole_id} not found in collar data")
#      48 if self.survey.empty:
#      49     raise ValueError(f"Hole {hole_id} not found in survey data")
#
# ValueError: Hole assays not found in collar data
